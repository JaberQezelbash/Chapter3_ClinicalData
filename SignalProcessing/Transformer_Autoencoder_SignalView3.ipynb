# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import LeaveOneOut
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.figure_factory as ff
import os  # For file operations

save_directory = r'C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder'

# Define the range of lambda values
lambdas = np.arange(0.5, 0.95, 0.05)

# Initialize dictionaries to store metrics for each lambda
metrics_dict = {l: {'accuracy': [], 'precision': [], 'recall': [], 'f1': [], 'specificity': []} for l in lambdas}
anomalies_report = {}

# Function to classify based on probability and threshold
def classify_with_reject(probabilities, threshold, initial_fp_fn_indices):
    predictions = []
    abstain_instances = []  # To store indices of abstain instances
    for i, prob in enumerate(probabilities):
        if i not in initial_fp_fn_indices:
            if prob >= 0.5:
                predictions.append(1)
            else:
                predictions.append(0)
        else:
            if prob >= threshold:
                predictions.append(1)  # Classify as positive if prob is >= threshold
            elif prob < 1 - threshold:
                predictions.append(0)  # Classify as negative if prob is < 1 - threshold
            else:
                predictions.append(-1)  # Reject classification for uncertain predictions
                abstain_instances.append(i)  # Record abstain instance index
    return np.array(predictions), abstain_instances

# Load new dataset
new_data_path = r"C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Datasets\ShandsData\combined_BPM_data.csv"
new_df = pd.read_csv(new_data_path)

# Store instance names
instance_names = new_df.iloc[:, 0].values  # Save the first column as instance names
new_df = new_df.iloc[:, 1:]

# Convert labels to binary (1 or 2 to 0 or 1)
new_df['label'] = new_df['label'].apply(lambda x: 0 if x == 1 else 1)

# Treat missing values with mean strategy only for numeric columns
numeric_columns = new_df.select_dtypes(include=[np.number]).columns
new_df[numeric_columns] = new_df[numeric_columns].fillna(new_df[numeric_columns].mean())

# Extract features (FHR time series) and labels
X_new_time_series = new_df.iloc[:, :-1].values  # Exclude the label column
y_new = new_df['label'].values  # Include the target variable y

# Autoencoder for Dimensionality Reduction
input_dim = X_new_time_series.shape[1]
encoding_dim = 30

input_layer = tf.keras.layers.Input(shape=(input_dim,))
encoder = tf.keras.layers.Dense(128, activation="relu")(input_layer)
encoder = tf.keras.layers.Dense(64, activation="relu")(encoder)
encoder = tf.keras.layers.Dense(encoding_dim, activation="relu")(encoder)
decoder = tf.keras.layers.Dense(64, activation='relu')(encoder)
decoder = tf.keras.layers.Dense(128, activation='relu')(decoder)
decoder = tf.keras.layers.Dense(input_dim, activation='sigmoid')(decoder)

autoencoder = tf.keras.models.Model(inputs=input_layer, outputs=decoder)
autoencoder.compile(optimizer='adam', loss='mse')

# Train the Autoencoder
autoencoder.fit(X_new_time_series, X_new_time_series, epochs=50, batch_size=32, shuffle=True, verbose=0)

# Encode the data
encoder_model = tf.keras.models.Model(inputs=input_layer, outputs=encoder)
X_new_time_series_reduced = encoder_model.predict(X_new_time_series)

# Revised Function to detect anomalies based on clinical definitions
def detect_fhr_anomalies(signal, fs=1):
    anomalies = {}
    time = np.arange(len(signal)) / fs  # Assuming sampling frequency fs

    # Baseline FHR (average over 10 minutes)
    window_size_baseline = fs * 10 * 60  # 10-minute window
    if len(signal) >= window_size_baseline:
        baseline = np.mean(signal[:int(window_size_baseline)])
    else:
        baseline = np.mean(signal)
    anomalies['baseline'] = baseline

    # Tachycardia and Bradycardia
    anomalies['tachycardia'] = baseline > 160
    anomalies['bradycardia'] = baseline < 110

    # Variability (using short-term variability)
    variability = []
    variability_times = []
    variability_categories = []
    window_size_variability = fs * 1 * 60  # 1-minute window
    for i in range(0, len(signal) - int(window_size_variability), int(window_size_variability)):
        segment = signal[i:i + int(window_size_variability)]
        std = np.std(segment)
        variability.append(std)
        variability_times.append(i / fs)
        # Variability Categories
        if std < 5:
            variability_categories.append('Absent or Minimal')
        elif 5 <= std <= 25:
            variability_categories.append('Moderate')
        elif std > 25:
            variability_categories.append('Marked')
        else:
            variability_categories.append('Unknown')

    anomalies['variability'] = variability
    anomalies['variability_category'] = variability_categories

    # Accelerations
    accelerations = []
    acceleration_times = []
    i = 0
    while i < len(signal) - fs * 15:
        if signal[i] - baseline >= 15:
            # Check if it lasts at least 15 seconds
            duration = 0
            while i + duration < len(signal) and signal[i + duration] - baseline >= 15:
                duration += 1
            if duration >= fs * 15:
                accelerations.append(i)
                acceleration_times.append(i / fs)
                i += duration
            else:
                i += 1
        else:
            i += 1

    anomalies['accelerations'] = accelerations

    # Decelerations
    decelerations = []
    deceleration_types = []
    deceleration_times = []
    i = 0
    while i < len(signal) - fs * 15:
        if baseline - signal[i] >= 15:
            decel_start = i
            # Find the nadir (lowest point)
            nadir = i
            while i < len(signal) and baseline - signal[i] >= 15:
                if signal[i] < signal[nadir]:
                    nadir = i
                i += 1
            decel_end = i
            duration = (decel_end - decel_start) / fs  # Duration in seconds

            # Determine type based on timing and shape (simplified)
            # In clinical practice, early decelerations mirror contractions; since we may not have contraction data, we focus on duration
            if duration < 2 * 60:
                deceleration_types.append('Variable')
            elif 2 * 60 <= duration <= 10 * 60:
                deceleration_types.append('Late')
            elif duration > 10 * 60:
                deceleration_types.append('Prolonged')
            else:
                deceleration_types.append('Unknown')
            decelerations.append(decel_start)
            deceleration_times.append(decel_start / fs)
        else:
            i += 1

    anomalies['decelerations'] = decelerations
    anomalies['deceleration_types'] = deceleration_types

    # Sinusoidal Pattern Detection (simplified)
    # Detecting a true sinusoidal pattern requires specific criteria
    anomalies['sinusoidal_pattern'] = False
    if all(cat == 'Absent or Minimal' for cat in variability_categories):
        # Check for regular oscillations
        fft = np.fft.fft(signal - baseline)
        freqs = np.fft.fftfreq(len(signal), d=1/fs)
        power = np.abs(fft)**2
        peak_freq = freqs[np.argmax(power[1:]) + 1]
        if 0.03 <= abs(peak_freq) <= 0.05:  # Sinusoidal frequency between 3-5 cycles per minute
            anomalies['sinusoidal_pattern'] = True

    return anomalies

# Detect anomalies in the full dataset
anomaly_indices_list = []
anomalies_report = {}
for idx in range(len(X_new_time_series)):
    signal = X_new_time_series[idx]
    anomalies = detect_fhr_anomalies(signal)
    anomalies_report[instance_names[idx]] = anomalies
    # For visualization, collect all anomaly indices
    anomaly_indices = np.unique(np.concatenate([
        anomalies.get('accelerations', []),
        anomalies.get('decelerations', [])
    ]))
    anomaly_indices_list.append(anomaly_indices)

# Leave-One-Out Cross Validation
loo = LeaveOneOut()

fold_number = 1
for train_index, test_index in loo.split(X_new_time_series_reduced):
    X_train_new, X_test_new = X_new_time_series_reduced[train_index], X_new_time_series_reduced[test_index]
    y_train_new, y_test_new = y_new[train_index], y_new[test_index]

    # Standardize the features (mean=0, std=1)
    scaler_time_series_new = StandardScaler()
    X_train_new_time_series = scaler_time_series_new.fit_transform(X_train_new)
    X_test_new_time_series = scaler_time_series_new.transform(X_test_new)

    # Reshape for Transformer input
    X_train_new_time_series = np.expand_dims(X_train_new_time_series, axis=2)
    X_test_new_time_series = np.expand_dims(X_test_new_time_series, axis=2)

    # Define the Transformer model
    def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
        # Normalization and Attention
        x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(inputs)
        x = tf.keras.layers.MultiHeadAttention(
            key_dim=head_size, num_heads=num_heads, dropout=dropout
        )(x, x)
        x = tf.keras.layers.Dropout(dropout)(x)
        res = x + inputs

        # Feed Forward Part
        x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(res)
        x = tf.keras.layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
        x = tf.keras.layers.Dropout(dropout)(x)
        x = tf.keras.layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
        return x + res

    def build_model(input_shape, head_size, num_heads, ff_dim, num_transformer_blocks, mlp_units, dropout=0, mlp_dropout=0):
        inputs = tf.keras.Input(shape=input_shape)
        x = inputs
        for _ in range(num_transformer_blocks):
            x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

        x = tf.keras.layers.GlobalAveragePooling1D(data_format="channels_first")(x)
        for dim in mlp_units:
            x = tf.keras.layers.Dense(dim, activation="relu")(x)
            x = tf.keras.layers.Dropout(mlp_dropout)(x)
        outputs = tf.keras.layers.Dense(1, activation="sigmoid")(x)
        return tf.keras.Model(inputs, outputs)

    input_shape = (X_train_new_time_series.shape[1], 1)
    transformer_model = build_model(
        input_shape,
        head_size=256,
        num_heads=4,
        ff_dim=4,
        num_transformer_blocks=4,
        mlp_units=[128],
        dropout=0.25,
        mlp_dropout=0.4,
    )

    transformer_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    # Train the model with early stopping
    best_model_new = None
    best_score_new = 0
    no_improvement_epochs_new = 0
    patience_new = 3  # Patience for early stopping

    for epoch in range(20):  # Number of epochs
        history_new = transformer_model.fit(X_train_new_time_series, y_train_new, epochs=1, batch_size=8, validation_split=0.1, verbose=0)

        # Evaluate on the training data
        train_accuracy_new = history_new.history['accuracy'][-1]
        
        # Check for early stopping
        if train_accuracy_new > best_score_new:
            best_model_new = transformer_model
            best_score_new = train_accuracy_new
            no_improvement_epochs_new = 0
        else:
            no_improvement_epochs_new += 1
        
        if no_improvement_epochs_new >= patience_new:
            print(f"Early stopping at epoch {epoch + 1}")
            break

    # Use the best model for predictions
    test_probabilities_new = best_model_new.predict(X_test_new_time_series).flatten()

    # Initial classification with lambda=0.5
    initial_predictions_new = (test_probabilities_new >= 0.5).astype(int)
    cm_initial_new = confusion_matrix(y_test_new, initial_predictions_new, labels=[0, 1])
    tn_initial_new, fp_initial_new, fn_initial_new, tp_initial_new = cm_initial_new.ravel()

    initial_fp_fn_indices_new = [i for i in range(len(initial_predictions_new)) if initial_predictions_new[i] != y_test_new[i]]

    # Initialize lists to store confusion matrix elements
    tp_list_new = []
    tn_list_new = []
    fp_list_new = []
    fn_list_new = []

    # Initialize a table to store results for each lambda
    table_data_new = []
    abstain_table_data_new = []
    metrics_table_data_new = []

    # Name of the tested instance in this fold
    tested_instance_name = instance_names[test_index[0]]
    print(f"Tested Instance in Fold {fold_number}: {tested_instance_name}")

    # Store anomaly detection results for the current fold
    anomalies_in_signal = anomalies_report[tested_instance_name]
    anomalies_report[tested_instance_name] = anomalies_in_signal

    # Loop through lambda values and calculate metrics
    for reject_threshold_new in lambdas:
        predictions_new, abstain_indices_new = classify_with_reject(test_probabilities_new, reject_threshold_new, initial_fp_fn_indices_new)
        
        # Filter out abstained instances
        filtered_indices_new = [i for i in range(len(predictions_new)) if predictions_new[i] != -1]
        y_test_filtered_new = y_test_new[filtered_indices_new]
        predictions_filtered_new = predictions_new[filtered_indices_new]
        
        # Calculate confusion matrix elements
        if len(predictions_filtered_new) > 0:
            cm_new = confusion_matrix(y_test_filtered_new, predictions_filtered_new, labels=[0, 1])
            tn_new, fp_new, fn_new, tp_new = cm_new.ravel()
        else:
            cm_new = np.array([[0, 0], [0, 0]])
            tn_new, fp_new, fn_new, tp_new = 0, 0, 0, 0

        # Append confusion matrix elements to lists
        tp_list_new.append(tp_new)
        tn_list_new.append(tn_new)
        fp_list_new.append(fp_new)
        fn_list_new.append(fn_new)
        
        # Append data to table
        table_data_new.append([round(reject_threshold_new, 2), tn_new, fp_new, fn_new, tp_new])
        
        # Report abstain instances (rows of data)
        abstain_instances_info_new = []
        for idx_new in abstain_indices_new:
            abstain_instances_info_new.append((idx_new, y_test_new[idx_new]))
        
        abstain_table_data_new.append([round(reject_threshold_new, 2), abstain_instances_info_new])

        # Calculate and store metrics
        if len(y_test_filtered_new) > 0:
            accuracy_new = accuracy_score(y_test_filtered_new, predictions_filtered_new) * 100
            precision_new = precision_score(y_test_filtered_new, predictions_filtered_new, zero_division=0) * 100
            recall_new = recall_score(y_test_filtered_new, predictions_filtered_new, zero_division=0) * 100
            f1_new = f1_score(y_test_filtered_new, predictions_filtered_new, zero_division=0) * 100
            specificity_new = (tn_new / (tn_new + fp_new)) * 100 if (tn_new + fp_new) > 0 else 0
        else:
            accuracy_new = precision_new = recall_new = f1_new = specificity_new = 0

        metrics_dict[reject_threshold_new]['accuracy'].append(accuracy_new)
        metrics_dict[reject_threshold_new]['precision'].append(precision_new)
        metrics_dict[reject_threshold_new]['recall'].append(recall_new)
        metrics_dict[reject_threshold_new]['f1'].append(f1_new)
        metrics_dict[reject_threshold_new]['specificity'].append(specificity_new)
        
        metrics_table_data_new.append([round(reject_threshold_new, 2), f"{accuracy_new:.2f}%", f"{precision_new:.2f}%", f"{recall_new:.2f}%", f"{f1_new:.2f}%", f"{specificity_new:.2f}%"])

        # Plot confusion matrix for this lambda
        if cm_new.shape != (2, 2):
            cm_padded_new = np.zeros((2, 2), dtype=int)
            cm_padded_new[:cm_new.shape[0], :cm_new.shape[1]] = cm_new
        else:
            cm_padded_new = cm_new

        x_labels_new = ['Normal', 'Abnormal']
        y_labels_new = ['Abnormal', 'Normal']  # Reverse the order of y_labels
        cm_reversed_new = cm_padded_new[::-1]
        fig_new = ff.create_annotated_heatmap(z=cm_reversed_new, x=x_labels_new, y=y_labels_new, colorscale='Blues')
        fig_new.update_layout(
            title=f'Confusion Matrix, Fold {fold_number}, Lambda {reject_threshold_new:.2f}',
            xaxis=dict(title='Predicted labels', tickfont=dict(size=10)),  # Adjust tick font size
            yaxis=dict(title='True labels', tickfont=dict(size=10)),  # Adjust tick font size
            width=400,  # Adjust width
            height=300,  # Adjust height
            margin=dict(l=50, r=50, t=130, b=50)  # Corrected margin specification
        )
        # Save the confusion matrix plot as an HTML file
        cm_html_path = os.path.join(save_directory, f'Confusion_Matrix_Fold_{fold_number}_Lambda_{reject_threshold_new:.2f}.html')
        fig_new.write_html(cm_html_path)
        print(f"Confusion matrix saved to {cm_html_path}")

    # Plot confusion matrix elements vs. lambda
    plt.figure(figsize=(8, 5))
    plt.plot(lambdas, tp_list_new, marker='o', linestyle='-', label='True Positives (TP)')
    plt.plot(lambdas, tn_list_new, marker='o', linestyle='-', label='True Negatives (TN)')
    plt.plot(lambdas, fp_list_new, marker='o', linestyle='-', label='False Positives (FP)')
    plt.plot(lambdas, fn_list_new, marker='o', linestyle='-', label='False Negatives (FN)')
    plt.xlabel('Lambda (Abstain Threshold)')
    plt.ylabel('Count')
    plt.title(f'Confusion Matrix Elements vs. Lambda Threshold, Fold {fold_number}')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Create a DataFrame for the table and display it
    df_table_cm_new = pd.DataFrame(table_data_new, columns=['Lambda Threshold', 'True Negatives (TN)', 'False Positives (FP)', 'False Negatives (FN)', 'True Positives (TP)'])
    # Save the DataFrame to an Excel file
    df_table_cm_new.to_excel(f'{save_directory}/Lambda_Abstain_Confusion_Matrix_Elements_Fold_{fold_number}.xlsx', index=False)
    print(f"Confusion matrix elements saved to {save_directory}/Lambda_Abstain_Confusion_Matrix_Elements_Fold_{fold_number}.xlsx")
  
    # Create a DataFrame for abstain instances table and display it
    df_abstain_table_new = pd.DataFrame(abstain_table_data_new, columns=['Lambda Threshold', 'Abstain Instances (Index, True Label)'])
    df_abstain_table_new['Tested Instance'] = tested_instance_name
    # Save the abstain instances DataFrame to an Excel file
    df_abstain_table_new.to_excel(f'{save_directory}/Lambda_Abstain_Instances_Fold_{fold_number}.xlsx', index=False)
    print(f"Abstain instances saved to {save_directory}/Lambda_Abstain_Instances_Fold_{fold_number}.xlsx")
    
    # Create a DataFrame for the performance metrics table and display it
    df_metrics_table_new = pd.DataFrame(metrics_table_data_new, columns=['Lambda Threshold', 'Accuracy', 'Precision', 'Recall', 'F1 Score', 'Specificity'])
    df_metrics_table_new['Tested Instance'] = tested_instance_name
    # Save the performance metrics DataFrame to an Excel file
    df_metrics_table_new.to_excel(f'{save_directory}/Lambda_Abstain_Results_Metrics_Fold_{fold_number}.xlsx', index=False)
    print(f"Performance metrics saved to {save_directory}/Lambda_Abstain_Results_Metrics_Fold_{fold_number}.xlsx")

    fold_number += 1

# Calculate average metrics for each lambda across all folds
avg_metrics_data_new = []
for l in lambdas:
    avg_accuracy_new = np.mean(metrics_dict[l]['accuracy'])
    avg_precision_new = np.mean(metrics_dict[l]['precision'])
    avg_recall_new = np.mean(metrics_dict[l]['recall'])
    avg_f1_new = np.mean(metrics_dict[l]['f1'])
    avg_specificity_new = np.mean(metrics_dict[l]['specificity'])
    
    avg_metrics_data_new.append([round(l, 2), f"{avg_accuracy_new:.2f}%", f"{avg_precision_new:.2f}%", f"{avg_recall_new:.2f}%", f"{avg_f1_new:.2f}%", f"{avg_specificity_new:.2f}%"])

# Create a DataFrame for average metrics and display it
df_avg_metrics_new = pd.DataFrame(avg_metrics_data_new, columns=['Lambda', 'Average Accuracy', 'Average Precision', 'Average Recall', 'Average F1-score', 'Average Specificity'])
# Save the average metrics DataFrame to an Excel file
df_avg_metrics_new.to_excel(f'{save_directory}/Average_Metrics_Per_Lambda.xlsx', index=False)
print(f"Average metrics per lambda saved to {save_directory}/Average_Metrics_Per_Lambda.xlsx")

# Plot the average performance metrics vs. lambda
plt.figure(figsize=(10, 6))
plt.plot(df_avg_metrics_new['Lambda'], df_avg_metrics_new['Average Accuracy'].str.rstrip('%').astype(float), marker='o', linestyle='-', label='Average Accuracy')
plt.plot(df_avg_metrics_new['Lambda'], df_avg_metrics_new['Average Precision'].str.rstrip('%').astype(float), marker='o', linestyle='-', label='Average Precision')
plt.plot(df_avg_metrics_new['Lambda'], df_avg_metrics_new['Average Recall'].str.rstrip('%').astype(float), marker='o', linestyle='-', label='Average Recall')
plt.plot(df_avg_metrics_new['Lambda'], df_avg_metrics_new['Average F1-score'].str.rstrip('%').astype(float), marker='o', linestyle='-', label='Average F1-score')
plt.plot(df_avg_metrics_new['Lambda'], df_avg_metrics_new['Average Specificity'].str.rstrip('%').astype(float), marker='o', linestyle='-', label='Average Specificity')
plt.xlabel('Lambda (Abstain Threshold)')
plt.ylabel('Percentage')
plt.title('Average Performance Metrics vs. Lambda Threshold')
plt.legend()
plt.grid(True)
plt.show()

print("\nAverage metrics for each lambda have been saved to 'Average_Metrics_Per_Lambda.xlsx'.")

# Final anomaly report
print("\nAnomaly Report:")
for instance, anomalies in anomalies_report.items():
    print(f"\nInstance: {instance}")
    print(f"Baseline FHR: {anomalies.get('baseline', 'N/A'):.2f} bpm")
    if anomalies.get('tachycardia'):
        print("Tachycardia detected (Baseline FHR > 160 bpm)")
    if anomalies.get('bradycardia'):
        print("Bradycardia detected (Baseline FHR < 110 bpm)")
    print(f"Variability Categories (per minute): {anomalies.get('variability_category', [])}")
    print(f"Number of Accelerations: {len(anomalies.get('accelerations', []))}")
    print(f"Number of Decelerations: {len(anomalies.get('decelerations', []))}")
    if anomalies.get('sinusoidal_pattern'):
        print("Sinusoidal pattern detected")

# Plotting long signal with anomalies using Plotly for scrolling and save as HTML
def plot_signal_with_anomalies_long(signal, anomalies, instance_name):
    fig = go.Figure()

    # Add the full signal trace
    fig.add_trace(go.Scatter(
        x=list(range(len(signal))),
        y=signal,
        mode='lines',
        name='Original Signal',
        line=dict(color='blue')
    ))

    # Highlight anomalies (both accelerations and decelerations) in red
    anomaly_indices = anomalies.get('accelerations', []) + anomalies.get('decelerations', [])
    if anomaly_indices:
        fig.add_trace(go.Scatter(
            x=anomaly_indices,
            y=signal[anomaly_indices],
            mode='markers',
            name='Anomalies',
            marker=dict(color='red', size=6)
        ))

    fig.update_layout(
        title=f'Signal with Anomalies for Instance: {instance_name}',
        xaxis_title='Time Step',
        yaxis_title='Signal Value',
        width=2000,  # Increase the width for better scrolling
        height=500,
        xaxis=dict(
            rangeslider=dict(visible=True),  # Enable range slider for scrolling through the x-axis
            type="linear"
        )
    )

    # Save the figure as an HTML file
    html_file_path = os.path.join(save_directory, f'Signal_With_Anomalies_{instance_name}.html')
    fig.write_html(html_file_path)
    print(f"Interactive signal plot saved to {html_file_path}")

# Loop through each instance and plot its signal with anomalies using Plotly
for instance, anomalies in anomalies_report.items():
    instance_index = np.where(instance_names == instance)[0][0]  # Get the index of the instance
    signal = X_new_time_series[instance_index]  # Get the original signal for the instance
    
    # Plot the signal with highlighted anomalies using Plotly for interactive scrolling
    plot_signal_with_anomalies_long(signal, anomalies, instance_name=instance)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Early stopping at epoch 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 770ms/step
# Tested Instance in Fold 1: Signal_10c
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_1_Lambda_0.50.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_1_Lambda_0.55.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_1_Lambda_0.60.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_1_Lambda_0.65.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_1_Lambda_0.70.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_1_Lambda_0.75.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_1_Lambda_0.80.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_1_Lambda_0.85.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_1_Lambda_0.90.html
# Confusion matrix elements saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Confusion_Matrix_Elements_Fold_1.xlsx
# Abstain instances saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Instances_Fold_1.xlsx
# Performance metrics saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Results_Metrics_Fold_1.xlsx
# Early stopping at epoch 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 808ms/step
# Tested Instance in Fold 2: Signal_13s
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_2_Lambda_0.50.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_2_Lambda_0.55.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_2_Lambda_0.60.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_2_Lambda_0.65.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_2_Lambda_0.70.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_2_Lambda_0.75.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_2_Lambda_0.80.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_2_Lambda_0.85.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_2_Lambda_0.90.html
# Confusion matrix elements saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Confusion_Matrix_Elements_Fold_2.xlsx
# Abstain instances saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Instances_Fold_2.xlsx
# Performance metrics saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Results_Metrics_Fold_2.xlsx
# Early stopping at epoch 6
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002281F370900> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 870ms/step
# Tested Instance in Fold 3: Signal_14c
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_3_Lambda_0.50.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_3_Lambda_0.55.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_3_Lambda_0.60.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_3_Lambda_0.65.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_3_Lambda_0.70.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_3_Lambda_0.75.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_3_Lambda_0.80.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_3_Lambda_0.85.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_3_Lambda_0.90.html
# Confusion matrix elements saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Confusion_Matrix_Elements_Fold_3.xlsx
# Abstain instances saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Instances_Fold_3.xlsx
# Performance metrics saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Results_Metrics_Fold_3.xlsx
# Early stopping at epoch 7
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000228433FD760> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 840ms/step
# Tested Instance in Fold 4: Signal_15c
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_4_Lambda_0.50.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_4_Lambda_0.55.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_4_Lambda_0.60.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_4_Lambda_0.65.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_4_Lambda_0.70.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_4_Lambda_0.75.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_4_Lambda_0.80.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_4_Lambda_0.85.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_4_Lambda_0.90.html
# Confusion matrix elements saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Confusion_Matrix_Elements_Fold_4.xlsx
# Abstain instances saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Instances_Fold_4.xlsx
# Performance metrics saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Results_Metrics_Fold_4.xlsx
# Early stopping at epoch 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 815ms/step
# Tested Instance in Fold 5: Signal_16s
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_5_Lambda_0.50.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_5_Lambda_0.55.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_5_Lambda_0.60.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_5_Lambda_0.65.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_5_Lambda_0.70.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_5_Lambda_0.75.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_5_Lambda_0.80.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_5_Lambda_0.85.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_5_Lambda_0.90.html
# Confusion matrix elements saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Confusion_Matrix_Elements_Fold_5.xlsx
# Abstain instances saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Instances_Fold_5.xlsx
# Performance metrics saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Results_Metrics_Fold_5.xlsx
# Early stopping at epoch 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# Tested Instance in Fold 6: Signal_17s
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_6_Lambda_0.50.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_6_Lambda_0.55.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_6_Lambda_0.60.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_6_Lambda_0.65.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_6_Lambda_0.70.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_6_Lambda_0.75.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_6_Lambda_0.80.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_6_Lambda_0.85.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_6_Lambda_0.90.html
# Confusion matrix elements saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Confusion_Matrix_Elements_Fold_6.xlsx
# Abstain instances saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Instances_Fold_6.xlsx
# Performance metrics saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Results_Metrics_Fold_6.xlsx
# Early stopping at epoch 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 810ms/step
# Tested Instance in Fold 7: Signal_18c
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_7_Lambda_0.50.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_7_Lambda_0.55.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_7_Lambda_0.60.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_7_Lambda_0.65.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_7_Lambda_0.70.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_7_Lambda_0.75.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_7_Lambda_0.80.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_7_Lambda_0.85.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_7_Lambda_0.90.html
# Confusion matrix elements saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Confusion_Matrix_Elements_Fold_7.xlsx
# Abstain instances saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Instances_Fold_7.xlsx
# Performance metrics saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Results_Metrics_Fold_7.xlsx
# Early stopping at epoch 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 861ms/step
# Tested Instance in Fold 8: Signal_20s
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_8_Lambda_0.50.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_8_Lambda_0.55.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_8_Lambda_0.60.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_8_Lambda_0.65.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_8_Lambda_0.70.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_8_Lambda_0.75.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_8_Lambda_0.80.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_8_Lambda_0.85.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_8_Lambda_0.90.html
# Confusion matrix elements saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Confusion_Matrix_Elements_Fold_8.xlsx
# Abstain instances saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Instances_Fold_8.xlsx
# Performance metrics saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Results_Metrics_Fold_8.xlsx
# Early stopping at epoch 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 867ms/step
# Tested Instance in Fold 9: Signal_21s
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_9_Lambda_0.50.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_9_Lambda_0.55.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_9_Lambda_0.60.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_9_Lambda_0.65.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_9_Lambda_0.70.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_9_Lambda_0.75.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_9_Lambda_0.80.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_9_Lambda_0.85.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_9_Lambda_0.90.html
# Confusion matrix elements saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Confusion_Matrix_Elements_Fold_9.xlsx
# Abstain instances saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Instances_Fold_9.xlsx
# Performance metrics saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Results_Metrics_Fold_9.xlsx
# Early stopping at epoch 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 800ms/step
# Tested Instance in Fold 10: Signal_23c
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_10_Lambda_0.50.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_10_Lambda_0.55.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_10_Lambda_0.60.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_10_Lambda_0.65.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_10_Lambda_0.70.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_10_Lambda_0.75.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_10_Lambda_0.80.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_10_Lambda_0.85.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_10_Lambda_0.90.html
# Confusion matrix elements saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Confusion_Matrix_Elements_Fold_10.xlsx
# Abstain instances saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Instances_Fold_10.xlsx
# Performance metrics saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Results_Metrics_Fold_10.xlsx
# Early stopping at epoch 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 769ms/step
# Tested Instance in Fold 11: Signal_25s
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_11_Lambda_0.50.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_11_Lambda_0.55.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_11_Lambda_0.60.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_11_Lambda_0.65.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_11_Lambda_0.70.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_11_Lambda_0.75.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_11_Lambda_0.80.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_11_Lambda_0.85.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_11_Lambda_0.90.html
# Confusion matrix elements saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Confusion_Matrix_Elements_Fold_11.xlsx
# Abstain instances saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Instances_Fold_11.xlsx
# Performance metrics saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Results_Metrics_Fold_11.xlsx
# Early stopping at epoch 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 760ms/step
# Tested Instance in Fold 12: Signal_26c
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_12_Lambda_0.50.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_12_Lambda_0.55.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_12_Lambda_0.60.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_12_Lambda_0.65.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_12_Lambda_0.70.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_12_Lambda_0.75.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_12_Lambda_0.80.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_12_Lambda_0.85.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_12_Lambda_0.90.html
# Confusion matrix elements saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Confusion_Matrix_Elements_Fold_12.xlsx
# Abstain instances saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Instances_Fold_12.xlsx
# Performance metrics saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Results_Metrics_Fold_12.xlsx
# Early stopping at epoch 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 797ms/step
# Tested Instance in Fold 13: Signal_27c
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_13_Lambda_0.50.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_13_Lambda_0.55.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_13_Lambda_0.60.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_13_Lambda_0.65.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_13_Lambda_0.70.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_13_Lambda_0.75.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_13_Lambda_0.80.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_13_Lambda_0.85.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_13_Lambda_0.90.html
# Confusion matrix elements saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Confusion_Matrix_Elements_Fold_13.xlsx
# Abstain instances saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Instances_Fold_13.xlsx
# Performance metrics saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Results_Metrics_Fold_13.xlsx
# Early stopping at epoch 11
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 860ms/step
# Tested Instance in Fold 14: Signal_28s
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_14_Lambda_0.50.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_14_Lambda_0.55.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_14_Lambda_0.60.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_14_Lambda_0.65.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_14_Lambda_0.70.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_14_Lambda_0.75.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_14_Lambda_0.80.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_14_Lambda_0.85.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_14_Lambda_0.90.html
# Confusion matrix elements saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Confusion_Matrix_Elements_Fold_14.xlsx
# Abstain instances saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Instances_Fold_14.xlsx
# Performance metrics saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Results_Metrics_Fold_14.xlsx
# Early stopping at epoch 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 782ms/step
# Tested Instance in Fold 15: Signal_30s
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_15_Lambda_0.50.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_15_Lambda_0.55.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_15_Lambda_0.60.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_15_Lambda_0.65.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_15_Lambda_0.70.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_15_Lambda_0.75.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_15_Lambda_0.80.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_15_Lambda_0.85.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_15_Lambda_0.90.html
# Confusion matrix elements saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Confusion_Matrix_Elements_Fold_15.xlsx
# Abstain instances saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Instances_Fold_15.xlsx
# Performance metrics saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Results_Metrics_Fold_15.xlsx
# Early stopping at epoch 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 887ms/step
# Tested Instance in Fold 16: Signal_34s
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_16_Lambda_0.50.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_16_Lambda_0.55.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_16_Lambda_0.60.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_16_Lambda_0.65.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_16_Lambda_0.70.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_16_Lambda_0.75.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_16_Lambda_0.80.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_16_Lambda_0.85.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_16_Lambda_0.90.html
# Confusion matrix elements saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Confusion_Matrix_Elements_Fold_16.xlsx
# Abstain instances saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Instances_Fold_16.xlsx
# Performance metrics saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Results_Metrics_Fold_16.xlsx
# Early stopping at epoch 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 773ms/step
# Tested Instance in Fold 17: Signal_35c
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_17_Lambda_0.50.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_17_Lambda_0.55.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_17_Lambda_0.60.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_17_Lambda_0.65.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_17_Lambda_0.70.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_17_Lambda_0.75.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_17_Lambda_0.80.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_17_Lambda_0.85.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_17_Lambda_0.90.html
# Confusion matrix elements saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Confusion_Matrix_Elements_Fold_17.xlsx
# Abstain instances saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Instances_Fold_17.xlsx
# Performance metrics saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Results_Metrics_Fold_17.xlsx
# Early stopping at epoch 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 842ms/step
# Tested Instance in Fold 18: Signal_36c
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_18_Lambda_0.50.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_18_Lambda_0.55.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_18_Lambda_0.60.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_18_Lambda_0.65.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_18_Lambda_0.70.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_18_Lambda_0.75.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_18_Lambda_0.80.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_18_Lambda_0.85.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_18_Lambda_0.90.html
# Confusion matrix elements saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Confusion_Matrix_Elements_Fold_18.xlsx
# Abstain instances saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Instances_Fold_18.xlsx
# Performance metrics saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder/Lambda_Abstain_Results_Metrics_Fold_18.xlsx
# Early stopping at epoch 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 779ms/step
# Tested Instance in Fold 19: Signal_37c
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_19_Lambda_0.50.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_19_Lambda_0.55.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_19_Lambda_0.60.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_19_Lambda_0.65.html
# Confusion matrix saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Confusion_Matrix_Fold_19_Lambda_0.70.html
# ...
# Number of Accelerations: 346
# Number of Decelerations: 3553
#
# Instance: Signal_7s
# Baseline FHR: 160.04 bpm
# Tachycardia detected (Baseline FHR > 160 bpm)
# Variability Categories (per minute): ['Moderate', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Moderate', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Moderate', 'Marked', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Moderate', 'Moderate', 'Absent or Minimal', 'Absent or Minimal', 'Moderate', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Moderate', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Moderate', 'Absent or Minimal', 'Absent or Minimal', 'Moderate', 'Absent or Minimal', 'Absent or Minimal', 'Moderate', 'Absent or Minimal', 'Absent or Minimal', 'Moderate', 'Marked', 'Marked', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Moderate', 'Moderate', 'Moderate', 'Absent or Minimal', 'Moderate', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Marked', 'Marked', 'Moderate', 'Marked', 'Moderate', 'Marked', 'Absent or Minimal', 'Moderate', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Moderate', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Moderate', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Moderate', 'Marked', 'Moderate', 'Moderate', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Moderate', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Moderate', 'Absent or Minimal', 'Marked', 'Marked', 'Marked', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Moderate', 'Marked', 'Moderate', 'Moderate', 'Moderate', 'Moderate', 'Absent or Minimal', 'Moderate', 'Moderate', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Moderate', 'Moderate', 'Moderate', 'Marked', 'Moderate', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Moderate', 'Moderate', 'Marked', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Moderate', 'Moderate', 'Moderate', 'Marked', 'Moderate', 'Marked', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Moderate', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Moderate', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Moderate', 'Absent or Minimal', 'Absent or Minimal', 'Moderate', 'Moderate', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Moderate', 'Marked', 'Moderate', 'Marked', 'Moderate', 'Moderate', 'Moderate', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Absent or Minimal', 'Moderate', 'Absent or Minima ...
# Number of Accelerations: 63
# Number of Decelerations: 3120
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_10c.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_13s.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_14c.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_15c.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_16s.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_17s.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_18c.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_20s.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_21s.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_23c.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_25s.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_26c.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_27c.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_28s.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_30s.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_34s.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_35c.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_36c.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_37c.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_39s.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_3c.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_40s.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_41c.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_42c.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_43s.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_44s.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_45s.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_46s.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_47s.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_48s.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_49s.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_50s.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_53s.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_54c.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_55c.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_56c.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_57c.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_58c.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_59c.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_5s.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_61c.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_62c.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_6c.html
# Interactive signal plot saved to C:\Users\Jaber\OneDrive - University of Florida\Educational\Chapters\Chapter1_Abstain\Codes\Results\Results_Transformer_Autoencoder\Signal_With_Anomalies_Signal_7s.html
